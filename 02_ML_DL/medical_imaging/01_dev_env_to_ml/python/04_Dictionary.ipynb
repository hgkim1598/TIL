# %% [markdown]
# ### ✅ Dictionary
# #### 🧩 key
# - 변경 불가능 (immutable)
#
# #### 🧩 value
# - 변경 가능 (mutable)
#
# => `{key: value}` 형식
#
# - 사전이라는 의미처럼 키를 활용하여 값을 찾는 자료형
# - 빠른 탐색이 가능하다

# %%
hospital_dict = {"내분비내과": 130, "정형외과": 122, "가정의학과": 342, "류마티스내과": 74}

# 키에 튜플 사용
dictionary_tuple = {(1, 5): 5, (3, 3): 3}

# 키에 float 사용
dictionary_float = {3.6: 5, "abc": 3}

# 키에 bool 사용
dictionary_bool = {True: 5, "abc": 3}

# %%
hospital_dict = {"내분비내과": 130, "정형외과": 122, "가정의학과": 342, "류마티스내과": 74} 

hospital_dict["정형외과"]

hospital_dict["치과"] = 35

del hospital_dict["정형외과"]

# hospital_dict["정형외과"] -> KeyError오류 발생. 지웠으니까!

print(hospital_dict)
# Out:
# {'내분비내과': 130, '가정의학과': 342, '류마티스내과': 74, '치과': 35}

# %% [markdown]
# ### 딕셔너리 추가 / 삭제
# - 딕셔너리는 [ ]대괄호 안에 키 값을 지정해주면 저장된 값을 불러올 수 있다
# - 이미 만들어진 딕셔너리에 대해서는 새로운 키를 대괄호에 작성하고 값을 넣어주면 된다
# - 이미 딕셔너리에 있는 값의 경우 새로운 값으로 업데이트된다
# - 찾고자 하는 딕셔너리에 키 값이 존재하지 않을 경우, 찾을 수 없음을 나타내는 KeyError를 반환한다
# #### 👉🏻 del
# - 저장되어 있는 딕셔너리의 항목을 삭제할 수 있다

# %%
# Dictionary
hospital_dict = dict()

hospital_dict['내분비내과'] = 10
hospital_dict["정형외과"] = 2

print(hospital_dict)
print(hospital_dict["가정의학과"])
# Out:
# {'내분비내과': 10, '정형외과': 2}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 8
#       5 hospital_dict["정형외과"] = 2
#       7 print(hospital_dict)
# ----> 8 print(hospital_dict["가정의학과"])
#
# KeyError: '가정의학과'

# %%
# DefaultDict
from collections import defaultdict
hospital_dict = defaultdict(int)  # 초기 자료형을 int로 설정

hospital_dict['내분비내과'] = 10
hospital_dict['정형외과'] = 2

print(hospital_dict)
print(hospital_dict['가정의학과'])
print(hospital_dict)
# Out:
# defaultdict(<class 'int'>, {'내분비내과': 10, '정형외과': 2})
# 0
# defaultdict(<class 'int'>, {'내분비내과': 10, '정형외과': 2, '가정의학과': 0})

# %% [markdown]
# ### Defaultdict
# - KeyError Exception을 해결하기 위해 딕셔너리와 유사한 `Defaultdict`를 활용할 수 있다
# - dict와 유사
# - 존재하지 않는 키를 조회하면 에러가 나는 대신 초기에 설정한 디폴트 자료형의 blank값을 기준으로 해당 키에 대한 아이템을 딕셔너리에 추가함

# %% [markdown]
# ### Q: 아래의 테이블을 활용하여 Department를 Key로, 환자수를 value로 하는 Dictionary를 생성하시오
#
# | Department | Number of Patients |
# |------------|--------------------|
# | 내분비내과 | 130 |
# | 정형외과 | 122 |
# | 가정의학과 | 342 |
# | 류마티스내과 | 74 |

# %%
hospital_dict = {'내분비내과': 130, '정형외과': 122, '가정의학과': 342, '류마티스내과': 74}

# %% [markdown]
# ### Q: 아래의 요구대로 list를 기본으로 하는 defaultdict을 생성하고 출력하시오
#
# | Department | Medicine |
# |------------|----------|
# | 내분비내과 | A, B, C, D, E |
# | 정형외과 | B, E |
# | 가정의학과 | A, E, F |
# | 류마티스내과 | C, G, H |
# 1) dept를 Key로, 약물을 담는 list를 value로 하는 Dictionary를 생성하시오
#
# 2) "흉부외과"를 dictionary에 추가 후 dictionary value를 확인하시오

# %%
# dept를 Key로, 약물을 담는 list를 value로 하는 Dictionary
from collections import defaultdict
medi_dict = defaultdict(list, {
    '내분비내과': ['A', 'B', 'C', 'D', 'E'],
    '정형외과': ['B', 'E'],
    '가정의학과': ['A', 'E', 'F'],
    '류마티스내과': ['C', 'G', 'H']
})

# "흉부외과"를 dictionary에 추가 후 dictionary value
medi_dict['흉부외과']
# Out:
# []
