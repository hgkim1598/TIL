# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 윈도우즈의 '맑은 고딕'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('x축')
plt.ylabel('y축')
plt.show()

# %% [markdown]
# # 여백 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, loc='right')
plt.xlabel('Y-Axis', labelpad=20, loc='top')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       3 plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
#       4 plt.xlabel('X-Axis', labelpad=15, loc='right')
# ----> 5 plt.xlabel('Y-Axis', labelpad=20, loc='top')
#       6 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:3027, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    3025 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    3026 def xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs):
# -> 3027     return gca().set_xlabel(
#    3028         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
#    3029         **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:3497, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3494 else:
#    3495     loc = (loc if loc is not None
#    3496            else mpl.rcParams['xaxis.labellocation'])
# -> 3497     _api.check_in_list(('left', 'center', 'right'), loc=loc)
#    3499     x = {
#    3500         'left': 0,
#    3501         'center': 0.5,
#    3502         'right': 1,
#    3503     }[loc]
#    3504     kwargs.update(x=x, horizontalalignment=loc)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\__init__.py:131, in check_in_list(_values, _print_supported_values, **kwargs)
#     129 if _print_supported_values:
#     130     msg += f"; supported values are {', '.join(map(repr, values))}"
# --> 131 raise ValueError(msg)
#
# ValueError: 'top' is not a valid value for loc; supported values are 'left', 'center', 'right'
